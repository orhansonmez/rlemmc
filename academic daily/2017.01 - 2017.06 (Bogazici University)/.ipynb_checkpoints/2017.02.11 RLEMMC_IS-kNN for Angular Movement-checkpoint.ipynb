# %%
% matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from rlemmc import environment, policy, trajectory, montecarlo

# %%
# Environment
horizon = 100
env = environment.AngularMovement()

# %%
# Inference
sampleCount = 1000
iterationCount = 100
selectedInference = montecarlo.importance_sampling

# %%
# Policy
kNearest = 5
policySampleCount = 10
p = policy.KnnPolicyContinuous(kNearest)

# %%
def plot_trajectories(states, color='red'):

    [sample_count, _, _] = states.shape

    for s in range(sample_count):
        plt.plot(states[s, :, 0], states[s, :, 1], '-', color=color)
        plt.plot(states[s, :, 0], states[s, :, 1], 'o', color=color)
        plt.plot(states[s, -1, 0], states[s, -1, 1], 'o', color=color)

# %%
def plot_iteration(states, newStates):
    plot_trajectories(states, color='red')
    plot_trajectories(newStates, color='green')
    plt.plot(env.targetState[0], env.targetState[1], 'o', color='blue', markersize=20)
    plt.grid()
    plt.show()

# %%
iterationRewards = []

for i in range(iterationCount):

    if i == 0:
        iterationPolicy = policy.UniformPolicyContinuous()
    else:
        iterationPolicy = p

    [states, actions, rewards] = \
        trajectory.rollout_trajectories(env, iterationPolicy, horizon, sampleCount)

    # E-Step
    [newStates, newActions] = selectedInference(states, actions, rewards[:,-1])

    # M-Step
    p.m_step(newStates, newActions)
    
    # Plot Trajectories
    # plot_iteration(states, newStates)
    
    # Average Reward
    iterationRewards.append(np.mean(rewards[:,-1]))
    print( f'Iteration {i+1} - Average Reward : {iterationRewards[i]}' )
# Out:
# Iteration 1 - Average Reward : 4.046634084139681e-05
# Iteration 2 - Average Reward : 0.0004395806818703872
# Iteration 3 - Average Reward : 0.0031673400777401882
# Iteration 4 - Average Reward : 0.017114865359981617
# Iteration 5 - Average Reward : 0.020828669165123204
# Iteration 6 - Average Reward : 0.025288664686278245
# Iteration 7 - Average Reward : 0.03277914684177835
# Iteration 8 - Average Reward : 0.05041418665706546
# Iteration 9 - Average Reward : 0.06546498818608057
# Iteration 10 - Average Reward : 0.09117596055349837
# Iteration 11 - Average Reward : 0.15022415523747723
# Iteration 12 - Average Reward : 0.20924635083336693
# Iteration 13 - Average Reward : 0.2085842966552962
# Iteration 14 - Average Reward : 0.29155080821112217
# Iteration 15 - Average Reward : 0.3954911904396342
# Iteration 16 - Average Reward : 0.4276642981755828
# Iteration 17 - Average Reward : 0.42272655373992274
# Iteration 18 - Average Reward : 0.4309870707923061
# Iteration 19 - Average Reward : 0.4734400555628489
# Iteration 20 - Average Reward : 0.4648100465139226
# Iteration 21 - Average Reward : 0.5129238667542335
# Iteration 22 - Average Reward : 0.466259162559001
# Iteration 23 - Average Reward : 0.5591798070879211
# Iteration 24 - Average Reward : 0.5274565520426147
# Iteration 25 - Average Reward : 0.5440280000143408
# Iteration 26 - Average Reward : 0.5748257027373168
# Iteration 27 - Average Reward : 0.5768422863905807
# Iteration 28 - Average Reward : 0.5126273052834499
# Iteration 29 - Average Reward : 0.5321059143663304
# Iteration 30 - Average Reward : 0.5536371525044594
# Iteration 31 - Average Reward : 0.5467003226088056
# Iteration 32 - Average Reward : 0.5190264775264943
# Iteration 33 - Average Reward : 0.47280536256722344
# Iteration 34 - Average Reward : 0.46733516119533297
# Iteration 35 - Average Reward : 0.4765351741388869
# Iteration 36 - Average Reward : 0.525392858353251
# Iteration 37 - Average Reward : 0.5114085250688715
