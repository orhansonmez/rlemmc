# %%
% matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import gym

from rlemmc import environment, policy, trajectory, montecarlo

# %%
# Environment
horizon = 200
env = environment.CartPoleEnvironment()
# Out:
# [2017-03-01 10:50:05,754] Making new env: CartPole-v0

# %%
# Inference
sampleCount = 200
iterationCount = 20
selectedInference = montecarlo.importance_sampling

# %%
# Policy
kNearest = 3
policySampleCount = 10
p = policy.KnnPolicyDiscrete(kNearest)

# %%
def plot_trajectories(states, color='red'):

    [sample_count, _, _] = states.shape

    for s in range(sample_count):
        plt.plot(states[s, :, 0], states[s, :, 2], '-', color=color)
        # plt.plot(states[s, :, 0], states[s, :, 2], 'o', color=color)
        plt.plot(states[s, -1, 0], states[s, -1, 2], 'o', color=color)

# %%
def plot_iteration(states, newStates):
    plot_trajectories(states, color='red')
    plot_trajectories(newStates, color='green')
    
    plt.vlines(0, -0.25, 0.25, linestyle='dotted')
    # plt.vlines(2.4, -0.25, 0.25, linestyle='dotted')
    # plt.vlines(-2.4, -0.25, 0.25, linestyle='dotted')
    
    plt.hlines(0, -2.4, 2.4, linestyle='dotted')
    plt.hlines(0.25, -2.4, 2.4, linestyle='dotted')
    plt.hlines(-0.25, -2.4, 2.4, linestyle='dotted')
    
    plt.grid()
    plt.show()

# %%
iterationRewards = []

for i in range(iterationCount):

    if i == 0:
        iterationPolicy = policy.UniformPolicyDiscrete(range(env.openAI.action_space.n))
    else:
        iterationPolicy = p

    [states, actions, rewards] = \
        trajectory.rollout_trajectories(env, iterationPolicy, horizon, sampleCount)

    # E-Step
    [newStates, newActions] = selectedInference(states, actions, np.sum(rewards, axis=1), policySampleCount)

    # M-Step
    p.m_step(newStates, newActions)
    
    # Plot Trajectories
    plot_iteration(states, newStates)
        
    # Average Reward
    iterationRewards.append(np.mean(rewards) * horizon)
    print( f'Iteration {i+1} - Average Reward : {iterationRewards[i]}' )
# Out:
# Iteration 1 - Average Reward : 21.475
# Iteration 2 - Average Reward : 26.015
# Iteration 3 - Average Reward : 38.905
# Iteration 4 - Average Reward : 39.905
# Iteration 5 - Average Reward : 52.42
# Iteration 6 - Average Reward : 55.76
# Iteration 7 - Average Reward : 55.464999999999996
# Iteration 8 - Average Reward : 69.0
# Iteration 9 - Average Reward : 73.0
# Iteration 10 - Average Reward : 80.08
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f28b6b6844f3> in <module>()
#       8         iterationPolicy = p
#       9
# ---> 10     [states, actions, rewards] =         trajectory.rollout_trajectories(env, iterationPolicy, horizon, sampleCount)
#      11
#      12     # E-Step
#
# C:\Dropbox\PhD\Python\RLEMMC\rlemmc\trajectory.py in rollout_trajectories(env, policy, horizon, sample_count)
#      34
#      35             # Action Selection
# ---> 36             actions[s, t, :] = policy.query(states[s, t, :])
#      37
#      38         _, rewards[s, horizon-1], _1, _2 = env.step(states[s, horizon-1, :], actions[s, horizon-1, :])
#
# C:\Dropbox\PhD\Python\RLEMMC\rlemmc\policy.py in query(self, inputs)
#      43         if len(inputs.shape) == 1:
#      44             inputs = inputs.reshape(1, -1)
# ---> 45         return self.knn.predict(inputs)
#      46
#      47     def train(self, inputs, targets):
#
# C:\Dropbox\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     162                 mode, _ = weighted_mode(_y[neigh_ind, k], weights, axis=1)
#     163
# --> 164             mode = np.asarray(mode.ravel(), dtype=np.intp)
#     165             y_pred[:, k] = classes_k.take(mode)
#     166
#
# C:\Dropbox\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     480
#     481     """
# --> 482     return array(a, dtype, copy=False, order=order)
#     483
#     484 def asanyarray(a, dtype=None, order=None):
#
# KeyboardInterrupt:

# %%
plt.plot(iterationRewards)
plt.show()
