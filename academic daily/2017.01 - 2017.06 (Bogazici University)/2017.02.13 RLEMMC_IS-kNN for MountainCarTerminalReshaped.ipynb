# %%
% matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import gym

from rlemmc import environment, policy, trajectory, montecarlo

# %%
# Environment
horizon = 100
env = environment.MountainCarTerminalReshapedEnvironment(horizon,0.1)
# Out:
# [2017-04-05 14:12:32,415] Making new env: MountainCar-v0

# %%
# Inference
sampleCount = 1000
iterationCount = 100
selectedInference = montecarlo.importance_sampling

# %%
# Policy
kNearest = 5
policySampleCount = 20
p = policy.KnnPolicyDiscrete(kNearest)

# %%
def plot_trajectories(states, color='red'):

    [sample_count, _, _] = states.shape

    for s in range(sample_count):
        plt.plot(states[s, :, 0], states[s, :, 1], '-', color=color)
        plt.plot(states[s, -1, 0], states[s, -1, 1], 'o', color=color)

# %%
def plot_iteration(states, newStates):
    plot_trajectories(states, color='red')
    plot_trajectories(newStates, color='green')
    plt.vlines(env.openAI.goal_position,-0.1,0.1,linestyle='dotted')
    plt.grid()
    plt.show()

# %%
iterationRewards = []

for i in range(iterationCount):

    if i == 0:
        iterationPolicy = policy.UniformPolicyDiscrete(range(env.openAI.action_space.n))
    else:
        iterationPolicy = p

    [states, actions, rewards] = \
        trajectory.rollout_trajectories(env, iterationPolicy, horizon, sampleCount)

    # E-Step
    [newStates, newActions] = selectedInference(states, actions, np.sum(rewards, axis=1), policySampleCount)

    # M-Step
    p.m_step(newStates, newActions)
    
    # Plot Trajectories
    plot_iteration(states, newStates)
        
    # Average Reward
    iterationRewards.append(np.mean(rewards) * horizon)
    print( f'Iteration {i+1} - Average Reward : {iterationRewards[i]}' )
# Out:
# Iteration 1 - Average Reward : 0.007636788379108199
# Iteration 2 - Average Reward : 0.00916615541017976
# Iteration 3 - Average Reward : 0.010160680152485026
# Iteration 4 - Average Reward : 0.01354481233572714
# Iteration 5 - Average Reward : 0.016913845704076755
# Iteration 6 - Average Reward : 0.01987297587432793
# Iteration 7 - Average Reward : 0.027269305612320927
# Iteration 8 - Average Reward : 0.04375901404850997
# Iteration 9 - Average Reward : 0.04365405960400817
# Iteration 10 - Average Reward : 0.04528612657048263
# Iteration 11 - Average Reward : 0.04731045655481384
# Iteration 12 - Average Reward : 0.04798970048957205
# Iteration 13 - Average Reward : 0.04579450618418073
# Iteration 14 - Average Reward : 0.043519075820996136
# Iteration 15 - Average Reward : 0.04570044818787076
# Iteration 16 - Average Reward : 0.0454649341582857
# Iteration 17 - Average Reward : 0.05097126086925596
# Iteration 18 - Average Reward : 0.05217924547571285
# Iteration 19 - Average Reward : 0.05479772045157774
# Iteration 20 - Average Reward : 0.055277800976400025
# Iteration 21 - Average Reward : 0.056996552936071136
# Iteration 22 - Average Reward : 0.05520227011914419
# Iteration 23 - Average Reward : 0.052597054745105794
# Iteration 24 - Average Reward : 0.05341437214613172
# Iteration 25 - Average Reward : 0.05288766380707581
# Iteration 26 - Average Reward : 0.04645252618314839
# Iteration 27 - Average Reward : 0.050215133817143924
# Iteration 28 - Average Reward : 0.050508231092563076
# Iteration 29 - Average Reward : 0.04614747489965882
# Iteration 30 - Average Reward : 0.048319394606994776
# Iteration 31 - Average Reward : 0.0535909470703055
# Iteration 32 - Average Reward : 0.05934045621238813
# Iteration 33 - Average Reward : 0.0649764213665455
# Iteration 34 - Average Reward : 0.06466555068486243
# Iteration 35 - Average Reward : 0.07043453182376246
